# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd 'drive/MyDrive/{path_to_repository}/{path_to_repository}/{library_name}'
# !pip3 install -e . -q
# !pip3 install nbdev -q
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/{path_to_repository}/{path_to_repository}/{library_name}'
# /content
# ERROR: File "setup.py" or "setup.cfg" not found. Directory cannot be installed in editable mode: /content

# %%
def hello_world(name):
  print(f"Hello {name} 😀")

# %%
hello_world("dirk")
# Out:
# Hello dirk 😀

# %% [markdown]
# some text ...

# %%
# %cd drive/MyDrive/nbdev_colab_tutorial/nbdev_colab_tutorial

# %%
# !ls
# Out:
# 00_core.ipynb		  docker-compose.yml  Makefile	    setup.py
# 01_happybeginning.ipynb   docs		      MANIFEST.in
# CONTRIBUTING.md		  index.ipynb	      README.md
# dirkiboys_nbdev_on_colab  LICENSE	      settings.ini
